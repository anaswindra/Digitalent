# %% [markdown]
# # Average Calories on Food and Beverages Menu Categories

# %%
import pandas as pd
data = 'menu.csv'
df_data=pd.read_csv(data, header=None)
# catatan, dengan ditambahkan header=None akan merubah data type
# sebaiknya dituliskan saja ->
df_data=pd.read_csv(data)

# %%
df_data.head(100)
# Out:
#           Category                                Item    Serving Size  \
# 0        Breakfast                        Egg McMuffin  4.8 oz (136 g)
# 1        Breakfast                   Egg White Delight  4.8 oz (135 g)
# 2        Breakfast                    Sausage McMuffin  3.9 oz (111 g)
# 3        Breakfast           Sausage McMuffin with Egg  5.7 oz (161 g)
# 4        Breakfast    Sausage McMuffin with Egg Whites  5.7 oz (161 g)
# ..             ...                                 ...             ...
# 95  Snacks & Sides  Ranch Snack Wrap (Grilled Chicken)  4.3 oz (121 g)
# 96  Snacks & Sides                  Small French Fries   2.6 oz (75 g)
# 97  Snacks & Sides                 Medium French Fries  3.9 oz (111 g)
# 98  Snacks & Sides                  Large French Fries  5.9 oz (168 g)
# 99  Snacks & Sides                   Kids French Fries   1.3 oz (38 g)
#
#     Calories  Calories from Fat  Total Fat  Total Fat (% Daily Value)  \
# ...

# %%
df_data.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
df_data.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
df_data.describe(include="all")
# Out:
#             Category                                 Item  Serving Size  \
# count            260                                  260           260
# unique             9                                  260           107
# top     Coffee & Tea  McFlurry with M&M’s Candies (Snack)  16 fl oz cup
# freq              95                                    1            45
# mean             NaN                                  NaN           NaN
# std              NaN                                  NaN           NaN
# min              NaN                                  NaN           NaN
# 25%              NaN                                  NaN           NaN
# 50%              NaN                                  NaN           NaN
# 75%              NaN                                  NaN           NaN
# max              NaN                                  NaN           NaN
#
#            Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# ...

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
df_data.describe(include="all")
# Out:
#             Category                                 Item  Serving Size  \
# count            260                                  260           260
# unique             9                                  260           107
# top     Coffee & Tea  McFlurry with M&M’s Candies (Snack)  16 fl oz cup
# freq              95                                    1            45
# mean             NaN                                  NaN           NaN
# std              NaN                                  NaN           NaN
# min              NaN                                  NaN           NaN
# 25%              NaN                                  NaN           NaN
# 50%              NaN                                  NaN           NaN
# 75%              NaN                                  NaN           NaN
# max              NaN                                  NaN           NaN
#
#            Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# ...

# %%
df_data.isnull().values.any()
# Out:
# False

# %%
df_data.Category.unique()
# Out:
# array(['Breakfast', 'Beef & Pork', 'Chicken & Fish', 'Salads',
#        'Snacks & Sides', 'Desserts', 'Beverages', 'Coffee & Tea',
#        'Smoothies & Shakes'], dtype=object)

# %%
df_data.loc[110:260, 'Category']
# Out:
# 110             Beverages
# 111             Beverages
# 112             Beverages
# 113             Beverages
# 114             Beverages
#               ...
# 255    Smoothies & Shakes
# 256    Smoothies & Shakes
# 257    Smoothies & Shakes
# 258    Smoothies & Shakes
# 259    Smoothies & Shakes
# Name: Category, Length: 150, dtype: object

# %%
import matplotlib.pyplot as plt
Bev = df_data.tail(150)

# %%
Bev_cal = pd.DataFrame({'Item': Bev.Item, 'Calories': Bev.Calories}) # Select only Items and Calories columns
Bev_sort = Bev_cal.sort_values('Calories', ascending=False) # Sort by calories
Bev_sort.plot.barh(x='Item', y='Calories', figsize= (10,45)) # Plot horizontal bar
plt.show()

# %%
food = df_data.head(110)
food_cal = pd.DataFrame({'Item': food.Item, 'Calories': food.Calories}) # Select only Items and Calories columns
food_sort = food_cal.sort_values('Calories', ascending=False) # Sort by calories
food_sort.plot.barh(x='Item', y='Calories', figsize= (10,45)) # Plot horizontal bar
plt.show()

# %%
Bev = df_data.tail(150)
avg_Bev = Bev['Calories'].mean(axis=0)
print("Average calories of all Bev is", round(avg_drink, 2))
# Out:
# Average calories of all Bev is 299.47

# %%
food = df_data.head(110)
avg_food = food['Calories'].mean(axis=0)
print("Average calories of all food is", round(avg_food, 2))
# Out:
# Average calories of all food is 462.09

# %%
avg_cal = pd.DataFrame({'Categories':['Beverages', 'Food'], 'Avg Calories': [avg_drink, avg_food]})
ax = avg_cal.plot.bar(x = 'Categories', y = 'Avg Calories', figsize=(7,5))
ax.set_title("Average Calories on Beverages and food Menu Categories (in Cal)")
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
